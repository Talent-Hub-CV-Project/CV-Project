# %%
from ultralytics import YOLO

model = YOLO(model='../models/yolov8n.pt')
# model = YOLO('../dataset/coco_dataset_one_class/coco.yaml').load('../models/yolov8n.pt')

# %%
model.train(data="../dataset/coco_dataset_one_class/coco.yaml", epochs=1, project="../models/", save_dir="../models/", name='yolov8n_custom')
# Out:
# New https://pypi.org/project/ultralytics/8.0.203 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.198 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 7940MiB)
# ...

# %%
metrics = model.val()
metrics
# Out:
# Ultralytics YOLOv8.0.198 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 7940MiB)
# Model summary (fused): 168 layers, 3006818 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /home/vorkov/Workspace/Python/CV-team/cv-team/CV-Project/dataset/coco_dataset/labels/val2017.cache... 378 images, 0 backgrounds, 0 corrupt: 100%|██████████| 378/378 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 947, len(boxes) = 954. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 24/24 [00:21<00:00,  1.13it/s]
#                    all        378        954      0.837      0.818      0.859      0.615
#                  horse        378        252      0.796      0.782       0.82        0.6
# ...

# %%
results = model("/home/vorkov/Documents/images2.jpeg")  # predict on an image
result = results[0]
box = result.boxes[0]
# Out:
# image 1/1 /home/vorkov/Documents/images2.jpeg: 448x640 1 animal, 96.6ms
# Speed: 12.6ms preprocess, 96.6ms inference, 29.5ms postprocess per image at shape (1, 3, 448, 640)

# %%
from PIL import Image
Image.fromarray(result.plot()[:,:,::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
path = model.export(path="../models", format="onnx")  # export the model to ONNX format
# Out:
# Traceback (most recent call last):
#
#   File ~/Workspace/Python/CV-team/cv-team/CV-Project/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3526 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[8], line 1
#     path = model.export(path="../models", format="onnx")  # export the model to ONNX format
#
#   File ~/Workspace/Python/CV-team/cv-team/CV-Project/venv/lib/python3.10/site-packages/ultralytics/engine/model.py:313 in export
#     return Exporter(overrides=args, _callbacks=self.callbacks)(model=self.model)
#
#   File ~/Workspace/Python/CV-team/cv-team/CV-Project/venv/lib/python3.10/site-packages/ultralytics/engine/exporter.py:145 in __init__
#     self.args = get_cfg(cfg, overrides)
#
#   File ~/Workspace/Python/CV-team/cv-team/CV-Project/venv/lib/python3.10/site-packages/ultralytics/cfg/__init__.py:113 in get_cfg
#     check_dict_alignment(cfg, overrides)
#
# ...
