# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# %%
# Use the model
# model.train(data="/home/vorkov/Workspace/Python/CV-team/cv-team/CV-Project/dataset/road_signs/data.yaml", epochs=3)  # train the model
model.train(data="/home/vorkov/Workspace/Python/CV-team/cv-team/CV-Project/dataset/coco_dataset/coco.yaml", epochs=8)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.0.200 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.198 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 7940MiB)
# ...

# %%
metrics = model.val()  # evaluate model performance on the validation set
metrics
# Out:
# Ultralytics YOLOv8.0.198 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 7940MiB)
# Model summary (fused): 168 layers, 3006818 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /home/vorkov/Workspace/Python/CV-team/cv-team/CV-Project/dataset/coco_dataset/labels/val2017.cache... 378 images, 0 backgrounds, 0 corrupt: 100%|██████████| 378/378 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 947, len(boxes) = 954. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 24/24 [00:21<00:00,  1.13it/s]
#                    all        378        954      0.837      0.818      0.859      0.615
#                  horse        378        252      0.796      0.782       0.82        0.6
# ...

# %%
results = model("/home/vorkov/Documents/images2.jpeg")  # predict on an image
result = results[0]
box = result.boxes[0]
# Out:
# image 1/1 /home/vorkov/Documents/images2.jpeg: 448x640 1 bear, 178.0ms
# Speed: 18.0ms preprocess, 178.0ms inference, 6.0ms postprocess per image at shape (1, 3, 448, 640)

# %%
from PIL import Image
Image.fromarray(result.plot()[:,:,::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
path = model.export(format="onnx")  # export the model to ONNX format
# Out:
# Ultralytics YOLOv8.0.198 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (AMD Ryzen 9 7940HS w/ Radeon 780M Graphics)
#
# PyTorch: starting from '/home/vorkov/Workspace/EDA/runs/detect/train28/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 10, 8400) (5.9 MB)
#
# ONNX: starting export with onnx 1.14.1 opset 17...
# ONNX: export success ✅ 2.7s, saved as '/home/vorkov/Workspace/EDA/runs/detect/train28/weights/best.onnx' (11.7 MB)
#
# Export complete (4.2s)
# Results saved to /home/vorkov/Workspace/EDA/runs/detect/train28/weights
# Predict:         yolo predict task=detect model=/home/vorkov/Workspace/EDA/runs/detect/train28/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=/home/vorkov/Workspace/EDA/runs/detect/train28/weights/best.onnx imgsz=640 data=/home/vorkov/Workspace/Python/CV-team/cv-team/CV-Project/dataset/coco_dataset/coco.yaml
# Visualize:       https://netron.app
